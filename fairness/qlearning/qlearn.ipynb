# %%
import random
import pickle
from typing import List
import numpy as np
from itertools import combinations, product
import pprint

import sys
import os
sys.path.append('..')
from utils import p, expected
print(os.getcwd())
# Out:
# c:\Users\joelj\Desktop\RoAR\fairness\qlearning

# %%
random.seed(0)

U_PLUS, U_MINUS = 1, -1.1
C_PLUS, C_MINUS = 10, -5
ALPHA = 5
MIN = -3
MAX = 3
BUCKETS_SIZE = 4
BUCKETS = list(range(-MIN, MAX, (MAX - MIN)/(BUCKETS_SIZE)))


MEAN_A, STD_A = 0.5, 1
MEAN_B, STD_B = 0.0, 1
SAMPLE_SIZE = 100

A = np.random.normal(MEAN_A, STD_A, SAMPLE_SIZE)
B = np.random.normal(MEAN_B, STD_B, SAMPLE_SIZE)

THRESHOLDS = [MIN, MAX]
ACTIONS = list(np.arange(MIN, MAX+0.1, 0.5))
ACTIONS = [float(x) for x in ACTIONS]
ACTIONS = list(product(ACTIONS, repeat=2))
pprint.pprint(ACTIONS)
# Out:
# [(-3.0, -3.0),
#  (-3.0, -2.5),
#  (-3.0, -2.0),
#  (-3.0, -1.5),
#  (-3.0, -1.0),
#  (-3.0, -0.5),
#  (-3.0, 0.0),
#  (-3.0, 0.5),
#  (-3.0, 1.0),
#  (-3.0, 1.5),
#  (-3.0, 2.0),
#  (-3.0, 2.5),
#  (-3.0, 3.0),
#  (-2.5, -3.0),
#  (-2.5, -2.5),
#  (-2.5, -2.0),
#  (-2.5, -1.5),
#  (-2.5, -1.0),
#  (-2.5, -0.5),
#  (-2.5, 0.0),
#  (-2.5, 0.5),
#  (-2.5, 1.0),
#  (-2.5, 1.5),
#  (-2.5, 2.0),
#  (-2.5, 2.5),
#  (-2.5, 3.0),
#  (-2.0, -3.0),
#  (-2.0, -2.5),
#  (-2.0, -2.0),
#  (-2.0, -1.5),
#  (-2.0, -1.0),
#  (-2.0, -0.5),
#  (-2.0, 0.0),
#  (-2.0, 0.5),
#  (-2.0, 1.0),
#  (-2.0, 1.5),
#  (-2.0, 2.0),
#  (-2.0, 2.5),
#  (-2.0, 3.0),
#  (-1.5, -3.0),
#  (-1.5, -2.5),
#  (-1.5, -2.0),
#  (-1.5, -1.5),
#  (-1.5, -1.0),
#  (-1.5, -0.5),
#  (-1.5, 0.0),
#  (-1.5, 0.5),
#  (-1.5, 1.0),
#  (-1.5, 1.5),
#  (-1.5, 2.0),
#  (-1.5, 2.5),
#  (-1.5, 3.0),
#  (-1.0, -3.0),
#  (-1.0, -2.5),
#  (-1.0, -2.0),
#  (-1.0, -1.5),
#  (-1.0, -1.0),
#  (-1.0, -0.5),
#  (-1.0, 0.0),
#  (-1.0, 0.5),
#  (-1.0, 1.0),
#  (-1.0, 1.5),
#  (-1.0, 2.0),
#  (-1.0, 2.5),
#  (-1.0, 3.0),
#  (-0.5, -3.0),
#  (-0.5, -2.5),
#  (-0.5, -2.0),
#  (-0.5, -1.5),
#  (-0.5, -1.0),
#  (-0.5, -0.5),
#  (-0.5, 0.0),
#  (-0.5, 0.5),
#  (-0.5, 1.0),
#  (-0.5, 1.5),
#  (-0.5, 2.0),
#  (-0.5, 2.5),
#  (-0.5, 3.0),
#  (0.0, -3.0),
#  (0.0, -2.5),
#  (0.0, -2.0),
#  (0.0, -1.5),
#  (0.0, -1.0),
#  (0.0, -0.5),
#  (0.0, 0.0),
#  (0.0, 0.5),
#  (0.0, 1.0),
#  (0.0, 1.5),
#  (0.0, 2.0),
#  (0.0, 2.5),
#  (0.0, 3.0),
#  (0.5, -3.0),
#  (0.5, -2.5),
#  (0.5, -2.0),
#  (0.5, -1.5),
#  (0.5, -1.0),
#  (0.5, -0.5),
#  (0.5, 0.0),
#  (0.5, 0.5),
#  (0.5, 1.0),
#  (0.5, 1.5),
#  (0.5, 2.0),
#  (0.5, 2.5),
#  (0.5, 3.0),
#  (1.0, -3.0),
#  (1.0, -2.5),
#  (1.0, -2.0),
#  (1.0, -1.5),
#  (1.0, -1.0),
#  (1.0, -0.5),
#  (1.0, 0.0),
#  (1.0, 0.5),
#  (1.0, 1.0),
#  (1.0, 1.5),
#  (1.0, 2.0),
#  (1.0, 2.5),
#  (1.0, 3.0),
#  (1.5, -3.0),
#  (1.5, -2.5),
#  (1.5, -2.0),
#  (1.5, -1.5),
#  (1.5, -1.0),
#  (1.5, -0.5),
#  (1.5, 0.0),
#  (1.5, 0.5),
#  (1.5, 1.0),
#  (1.5, 1.5),
#  (1.5, 2.0),
#  (1.5, 2.5),
#  (1.5, 3.0),
#  (2.0, -3.0),
#  (2.0, -2.5),
#  (2.0, -2.0),
#  (2.0, -1.5),
#  (2.0, -1.0),
#  (2.0, -0.5),
#  (2.0, 0.0),
#  (2.0, 0.5),
#  (2.0, 1.0),
#  (2.0, 1.5),
#  (2.0, 2.0),
#  (2.0, 2.5),
#  (2.0, 3.0),
#  (2.5, -3.0),
#  (2.5, -2.5),
#  (2.5, -2.0),
#  (2.5, -1.5),
#  (2.5, -1.0),
#  (2.5, -0.5),
#  (2.5, 0.0),
#  (2.5, 0.5),
#  (2.5, 1.0),
#  (2.5, 1.5),
#  (2.5, 2.0),
#  (2.5, 2.5),
#  (2.5, 3.0),
#  (3.0, -3.0),
#  (3.0, -2.5),
#  (3.0, -2.0),
#  (3.0, -1.5),
#  (3.0, -1.0),
#  (3.0, -0.5),
#  (3.0, 0.0),
#  (3.0, 0.5),
#  (3.0, 1.0),
#  (3.0, 1.5),
#  (3.0, 2.0),
#  (3.0, 2.5),
#  (3.0, 3.0)]

# %%
class State:
    '''
    The state is represented by x buckets, where each bucket holds all samples in y-z% of the distribtution
    4 buckets, bucket 1 holds 0-25%, bucket 2 holds 25-50%, etc.
    A unique state would be a tuple of the number of samples in each bucket
    10 Samples : buckets_a(2, 4, 3, 1), buckets_b(1, 3, 5, 1)
    ''' 
    def __init__(self, env, buckets_a : tuple[int], buckets_b : tuple[int], mean_diff, steps):
        self.env = env
        self.buckets_a = buckets_a
        self.buckets_b = buckets_b
        self.mean_diff = mean_diff
        self.steps = steps
        
    def clone(self):
        from copy import deepcopy
        new_env = deepcopy(self.env)
        return State(new_env, self.buckets_a, self.buckets_b, self.mean_diff, self.steps)


    def reward(self):
        '''
        Calculate utility
        Penalty if mean difference > ALPHA
        '''
        if self.mean_diff > ALPHA:
            return 0
        
        util_a = self.env.w_a * np.sum(expected(self.env.a, U_PLUS, U_MINUS))
        util_b = self.env.w_b * np.sum(expected(self.env.b, U_PLUS, U_MINUS))
        return (util_a + util_b)

    def at_end(self) -> bool:
        '''
        Step size lower than n steps
        '''
        return self.steps > 2

    def execute(self, action):
        '''
        Calculate expected change; apply it to values above the threshold(action), get new samples
        Calculate percentiles of the new samples, update buckets
        '''
        thresh_a, thresh_b = action
        delta_A, delta_B = expected(self.env.a, C_PLUS, C_MINUS), expected(self.env.b, C_PLUS, C_MINUS)
       
        self.env.a = np.where(self.env.a > thresh_a, self.env.a + delta_A, self.env.a)
        self.env.b = np.where(self.env.b > thresh_b, self.env.b + delta_B, self.env.b)

        q1_a, q2_a, q3_a = np.percentile(self.env.a, [25, 50, 75])
        q1_b, q2_b, q3_b = np.percentile(self.env.b, [25, 50, 75])

        a0, b0 = np.sum(self.env.a <= q1_a), np.sum(self.env.b <= q1_b)
        a1, b1 = np.sum((self.env.a > q1_a) & (self.env.a <= q2_a)), np.sum((self.env.b > q1_b) & (self.env.b <= q2_b))
        a2, b2 = np.sum((self.env.a > q2_a) & (self.env.a <= q3_a)), np.sum((self.env.b > q2_b) & (self.env.b <= q3_b))
        a3, b3 = np.sum(self.env.a > q3_a), np.sum(self.env.b > q3_b)

        self.buckets_a = (a0, a1, a2, a3)
        self.buckets_b = (b0, b1, b2, b3)
        
        self.mean_diff = np.abs(np.mean(self.env.a) - np.mean(self.env.b))
        self.steps += 1

        return self

    def __str__(self):
        return f'''
        buckets_a={self.buckets_a}, 
        buckets_b={self.buckets_b},
        mean_diff={self.mean_diff:.2f},
        reward={self.reward():.2f},
        '''

# %%
class Env:

    def __init__(self, a : List[float], b: List[float]):
        self.a = a
        self.b = b
        self.w_a = len(a) / (len(a) + len(b))
        self.w_b = 1 - self.w_a

    def random_state(self):
        self.a = A
        self.b = B

        q1_a, q2_a, q3_a = np.percentile(self.a, [25, 50, 75])
        q1_b, q2_b, q3_b = np.percentile(self.b, [25, 50, 75])

        buckets_a = [0] * BUCKETS
        buckets_b = [0] * BUCKETS

        buckets_a[0], buckets_b[0] = np.sum(self.a <= q1_a), np.sum(self.b <= q1_b)
        buckets_a[1], buckets_b[1] = np.sum((self.a > q1_a) & (self.a <= q2_a)), np.sum((self.b > q1_b) & (self.b <= q2_b))
        buckets_a[2], buckets_b[2] = np.sum((self.a > q2_a) & (self.a <= q3_a)), np.sum((self.b > q2_b) & (self.b <= q3_b))
        buckets_a[3], buckets_b[3] = np.sum(self.a > q3_a), np.sum(self.b > q3_b)

        mean_diff = np.abs(np.mean(self.a) - np.mean(self.b))
        steps = 0

        return State(self, buckets_a, buckets_b, mean_diff, steps)

# %%
class QTable:
    def __init__(self, env: Env, actions: List[List[int]]):
        self.env = env
        self.actions = actions
        self.qtable = {}

    def get_q(self, state: State, action: tuple[int]) -> float:
        '''return the value of the q table for the given state, action'''
        buckets_a = tuple(state.buckets_a)
        buckets_b = tuple(state.buckets_b)
        action = tuple(action)
        if (buckets_a, buckets_b) not in self.qtable:
            self.qtable[(buckets_a, buckets_b)] = {pair : 0 for pair in self.actions}
        return self.qtable[(buckets_a, buckets_b)][action]

    def get_q_row(self, state: State) -> List[float]:
        '''return the row of q table corresponding to the given state, aka actions and their values'''
        buckets_a = tuple(state.buckets_a)
        buckets_b = tuple(state.buckets_b)
        if (buckets_a, buckets_b) not in self.qtable:
            self.qtable[(buckets_a, buckets_b)] = {pair : 0 for pair in self.actions}
        return self.qtable[(buckets_a, buckets_b)]

    def set_q(self, state: State, action: List[int], val: float) -> None:
        '''set the value of the q table for the given state, action'''
        buckets_a = tuple(state.buckets_a)
        buckets_b = tuple(state.buckets_b)
        action = tuple(action)

        if (buckets_a, buckets_b) not in self.qtable:
            self.qtable[(buckets_a, buckets_b)] = {pair : 0 for pair in self.actions}
        self.qtable[(buckets_a, buckets_b)][action] = val

    def learn_episode(self, alpha: float = .10, gamma: float = .90) -> None:
        # from a random initial state,
        state = self.env.random_state()
        # repeat until an end state is reached (thus completing the episode)
        while not state.at_end():
            # consider a random legal action, execute that action,
            action = random.choice(ACTIONS)
            
            prev_state = state.clone()
            
            print(action)
            #print(f"Percentiles before: {np.percentile(self.env.a, [25, 50, 75])}")
            #state.execute(action)
            #print(f"Percentiles after: {np.percentile(self.env.a, [25, 50, 75])}")
            #print(state)

            #'''
            # Get the percentiles
            percentiles_before = np.percentile(self.env.a, [25, 50, 75])
            p25, p50, p75 = percentiles_before

            # Count how many values fall into each quartile before
            a = self.env.a
            q1 = np.sum(a <= p25)
            q2 = np.sum((a > p25) & (a <= p50))
            q3 = np.sum((a > p50) & (a <= p75))
            q4 = np.sum(a > p75)

            print(f"Percentiles before: {percentiles_before}")
            print(f"Counts before: Q1 (0–25%): {q1}, Q2 (25–50%): {q2}, Q3 (50–75%): {q3}, Q4 (75–100%): {q4}")

            # Execute the action
            state.execute(action)

            # Get the percentiles after the action
            percentiles_after = np.percentile(self.env.a, [25, 50, 75])
            p25, p50, p75 = percentiles_after

            # Count values in each percentile after
            a = self.env.a
            q1 = np.sum(a <= p25)
            q2 = np.sum((a > p25) & (a <= p50))
            q3 = np.sum((a > p50) & (a <= p75))
            q4 = np.sum(a > p75)

            print(f"Percentiles after: {percentiles_after}")
            print(f"Counts after: Q1 (0–25%): {q1}, Q2 (25–50%): {q2}, Q3 (50–75%): {q3}, Q4 (75–100%): {q4}")

            print(state)
            #'''
            
            # with the given alpha and gamma values,
            # compute the reward, and update the q table for (state, action).
            max_q = max(self.get_q_row(state).values())
            sample = state.reward() + gamma * max_q
            new_qvalue = ((1 - alpha) * self.get_q(prev_state, action)) + (alpha * sample)
            self.set_q(prev_state, action, new_qvalue)
            
    def learn(self, episodes, alpha=.10, gamma=.90) -> None:
        # run <episodes> number of episodes for learning with the given alpha and gamma
        for episode in range(episodes):
            self.learn_episode(alpha, gamma)

    def __str__(self) -> str:
        import pprint

        pprint.pprint(self.qtable)

        return ""

# %%
if __name__ == "__main__":

    env = Env(A, B)
    try:
        with open("qtable.pkl", "rb") as f:
            qt = pickle.load(f)
    except:
        qt = QTable(env, ACTIONS)

    qt.learn(100)

    with open("qtable.pkl", "wb") as f:
        
        pickle.dump(qt, f)
    print(qt)
# Out:
# (0.5, 0.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819  7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=0.76,
#         reward=29.33,
#
# (1.0, -1.5)
# Percentiles before: [-0.23913282  0.31439819  7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819 17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=0.52,
#         reward=42.54,
#
# (-3.0, 2.0)
# Percentiles before: [-0.23913282  0.31439819 17.20430245]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 1.36837585  3.98376337 27.20430194]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=0.46,
#         reward=56.74,
#
# (-0.5, -2.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=1.04,
#         reward=56.12,
#
# (2.0, -3.0)
# Percentiles before: [1.36837585 3.98376337 7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 1.36837585 13.7095212  17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=1.56,
#         reward=61.08,
#
# (1.5, 0.5)
# Percentiles before: [ 1.36837585 13.7095212  17.20430245]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 1.36837585 23.70950452 27.20430194]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=1.20,
#         reward=62.05,
#
# (0.5, 3.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819  7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=3.21,
#         reward=18.56,
#
# (-0.5, 3.0)
# Percentiles before: [-0.23913282  0.31439819  7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 1.36837585  3.98376337 17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=8.74,
#         reward=0.00,
#
# (1.5, -0.5)
# Percentiles before: [ 1.36837585  3.98376337 17.20430245]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 1.36837585 13.7095212  27.20430194]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=12.55,
#         reward=0.00,
#
# (0.5, -3.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819  7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=0.19,
#         reward=41.53,
#
# (2.5, 0.0)
# Percentiles before: [-0.23913282  0.31439819  7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819 17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=2.19,
#         reward=45.96,
#
# (-1.0, -1.5)
# Percentiles before: [-0.23913282  0.31439819 17.20430245]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 1.36837585  3.98376337 27.20430194]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=4.26,
#         reward=60.09,
#
# (1.5, 3.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819  1.06401545]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=1.47,
#         reward=9.83,
#
# (-2.0, 1.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=5.04,
#         reward=0.00,
#
# (-0.5, 0.5)
# Percentiles before: [1.36837585 3.98376337 7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 8.32458759 13.7095212  17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=10.12,
#         reward=0.00,
#
# (-2.0, 1.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=3.44,
#         reward=32.62,
#
# (-2.5, 2.5)
# Percentiles before: [1.36837585 3.98376337 7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 8.32458759 13.7095212  17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=10.22,
#         reward=0.00,
#
# (3.0, -2.0)
# Percentiles before: [ 8.32458759 13.7095212  17.20430245]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [18.32093406 23.70950452 27.20430194]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=15.10,
#         reward=0.00,
#
# (-1.0, 3.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=4.11,
#         reward=32.50,
#
# (2.0, 0.0)
# Percentiles before: [1.36837585 3.98376337 7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 1.36837585 13.7095212  17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=8.23,
#         reward=0.00,
#
# (2.5, 2.5)
# Percentiles before: [ 1.36837585 13.7095212  17.20430245]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 1.36837585 23.70950452 27.20430194]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=9.91,
#         reward=0.00,
#
# (-2.0, 2.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=4.00,
#         reward=31.67,
#
# (0.0, -2.5)
# Percentiles before: [1.36837585 3.98376337 7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 8.32458759 13.7095212  17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=8.52,
#         reward=0.00,
#
# (-2.5, 3.0)
# Percentiles before: [ 8.32458759 13.7095212  17.20430245]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [18.32093406 23.70950452 27.20430194]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=11.03,
#         reward=0.00,
#
# (-2.5, -0.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=0.62,
#         reward=56.80,
#
# (0.0, 0.0)
# Percentiles before: [1.36837585 3.98376337 7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 8.32458759 13.7095212  17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=1.28,
#         reward=65.09,
#
# (1.5, -1.5)
# Percentiles before: [ 8.32458759 13.7095212  17.20430245]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [18.32093406 23.70950452 27.20430194]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=1.97,
#         reward=63.94,
#
# (2.5, -3.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819  1.06401545]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=2.79,
#         reward=30.21,
#
# (-2.5, 3.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=4.55,
#         reward=55.11,
#
# (0.0, 3.0)
# Percentiles before: [1.36837585 3.98376337 7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 8.32458759 13.7095212  17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=2.53,
#         reward=59.04,
#
# (1.0, 0.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819  7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=0.24,
#         reward=23.14,
#
# (0.0, -2.0)
# Percentiles before: [-0.23913282  0.31439819  7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  3.98376337 17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=0.60,
#         reward=50.63,
#
# (3.0, -3.0)
# Percentiles before: [-0.23913282  3.98376337 17.20430245]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282 13.7095212  27.20430194]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=1.16,
#         reward=54.19,
#
# (3.0, 0.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819  1.06401545]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=2.21,
#         reward=18.02,
#
# (-1.0, -3.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=2.90,
#         reward=55.55,
#
# (2.0, 2.5)
# Percentiles before: [1.36837585 3.98376337 7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 1.36837585 13.7095212  17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=1.45,
#         reward=57.63,
#
# (1.5, -0.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819  1.06401545]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=1.91,
#         reward=34.96,
#
# (1.0, 1.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819  7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=6.05,
#         reward=0.00,
#
# (2.0, -1.5)
# Percentiles before: [-0.23913282  0.31439819  7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819 17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=10.46,
#         reward=0.00,
#
# (-0.5, -2.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=1.04,
#         reward=56.12,
#
# (-2.5, -2.0)
# Percentiles before: [1.36837585 3.98376337 7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 8.32458759 13.7095212  17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=1.68,
#         reward=61.96,
#
# (2.0, 2.0)
# Percentiles before: [ 8.32458759 13.7095212  17.20430245]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [18.32093406 23.70950452 27.20430194]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=2.18,
#         reward=62.04,
#
# (-3.0, -1.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=0.67,
#         reward=55.45,
#
# (-2.5, 2.0)
# Percentiles before: [1.36837585 3.98376337 7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 8.32458759 13.7095212  17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=1.83,
#         reward=60.39,
#
# (0.5, 2.5)
# Percentiles before: [ 8.32458759 13.7095212  17.20430245]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [18.32093406 23.70950452 27.20430194]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=3.66,
#         reward=60.88,
#
# (3.0, -1.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819  1.06401545]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=3.09,
#         reward=31.59,
#
# (-3.0, -3.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=5.87,
#         reward=0.00,
#
# (3.0, -3.0)
# Percentiles before: [1.36837585 3.98376337 7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 1.36837585 13.7095212  17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=7.40,
#         reward=0.00,
#
# (1.5, 1.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819  1.06401545]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=0.90,
#         reward=10.78,
#
# (0.0, 0.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  3.98376337  7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=2.32,
#         reward=38.02,
#
# (-1.0, 2.0)
# Percentiles before: [-0.23913282  3.98376337  7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 1.36837585 13.7095212  17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=5.06,
#         reward=0.00,
#
# (0.0, -0.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  3.98376337  7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=0.49,
#         reward=52.37,
#
# (-2.5, -1.5)
# Percentiles before: [-0.23913282  3.98376337  7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 1.36837585 13.7095212  17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=0.23,
#         reward=60.67,
#
# (-1.5, 1.5)
# Percentiles before: [ 1.36837585 13.7095212  17.20430245]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 8.32458759 23.70950452 27.20430194]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=0.38,
#         reward=64.32,
#
# (2.5, -2.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819  1.06401545]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=2.94,
#         reward=30.55,
#
# (-1.0, -1.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=6.06,
#         reward=0.00,
#
# (-1.0, 1.5)
# Percentiles before: [1.36837585 3.98376337 7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 8.32458759 13.7095212  17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=5.99,
#         reward=0.00,
#
# (-2.0, 2.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=3.83,
#         reward=31.84,
#
# (2.0, 1.5)
# Percentiles before: [1.36837585 3.98376337 7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 1.36837585 13.7095212  17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=10.42,
#         reward=0.00,
#
# (1.0, 2.0)
# Percentiles before: [ 1.36837585 13.7095212  17.20430245]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 8.32458759 23.70950452 27.20430194]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=17.45,
#         reward=0.00,
#
# (-2.5, 2.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=3.83,
#         reward=31.84,
#
# (-2.5, 0.5)
# Percentiles before: [1.36837585 3.98376337 7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 8.32458759 13.7095212  17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=8.84,
#         reward=0.00,
#
# (0.0, -1.5)
# Percentiles before: [ 8.32458759 13.7095212  17.20430245]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [18.32093406 23.70950452 27.20430194]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=12.36,
#         reward=0.00,
#
# (2.0, -3.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819  1.06401545]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=2.62,
#         reward=30.45,
#
# (1.5, 1.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819  1.06401545]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=8.09,
#         reward=0.00,
#
# (-2.0, -2.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=11.07,
#         reward=0.00,
#
# (-0.5, 3.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=4.15,
#         reward=33.04,
#
# (2.0, 2.5)
# Percentiles before: [1.36837585 3.98376337 7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 1.36837585 13.7095212  17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=11.33,
#         reward=0.00,
#
# (-0.5, 1.5)
# Percentiles before: [ 1.36837585 13.7095212  17.20430245]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 8.32458759 23.70950452 27.20430194]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=18.59,
#         reward=0.00,
#
# (-2.0, -0.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=0.62,
#         reward=56.80,
#
# (2.0, 2.0)
# Percentiles before: [1.36837585 3.98376337 7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 1.36837585 13.7095212  17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=1.48,
#         reward=59.57,
#
# (0.0, 0.5)
# Percentiles before: [ 1.36837585 13.7095212  17.20430245]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 8.32458759 23.70950452 27.20430194]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=2.22,
#         reward=64.65,
#
# (2.0, 1.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819  1.06401545]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=0.95,
#         reward=11.31,
#
# (-1.0, -3.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=0.61,
#         reward=55.48,
#
# (2.5, 2.5)
# Percentiles before: [1.36837585 3.98376337 7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 1.36837585 13.7095212  17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=0.16,
#         reward=56.87,
#
# (2.0, 2.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819  1.06401545]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=0.23,
#         reward=7.64,
#
# (2.5, 0.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819  1.06401545]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=2.04,
#         reward=18.25,
#
# (-0.5, 1.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=2.09,
#         reward=43.89,
#
# (1.0, 1.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819  7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=1.64,
#         reward=13.32,
#
# (-2.5, 2.0)
# Percentiles before: [-0.23913282  0.31439819  7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 1.36837585  3.98376337 17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=5.44,
#         reward=0.00,
#
# (2.5, 1.5)
# Percentiles before: [ 1.36837585  3.98376337 17.20430245]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 1.36837585 13.7095212  27.20430194]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=11.23,
#         reward=0.00,
#
# (0.5, 0.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819  7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=0.76,
#         reward=29.33,
#
# (0.0, -1.5)
# Percentiles before: [-0.23913282  0.31439819  7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  3.98376337 17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=1.18,
#         reward=51.23,
#
# (2.5, -1.0)
# Percentiles before: [-0.23913282  3.98376337 17.20430245]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282 13.7095212  27.20430194]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=0.67,
#         reward=57.03,
#
# (-1.0, 1.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=3.55,
#         reward=33.45,
#
# (-0.5, 1.5)
# Percentiles before: [1.36837585 3.98376337 7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 8.32458759 13.7095212  17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=10.51,
#         reward=0.00,
#
# (-1.5, 1.0)
# Percentiles before: [ 8.32458759 13.7095212  17.20430245]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [18.32093406 23.70950452 27.20430194]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=17.29,
#         reward=0.00,
#
# (-1.5, 1.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=3.51,
#         reward=33.10,
#
# (-1.5, 1.0)
# Percentiles before: [1.36837585 3.98376337 7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 8.32458759 13.7095212  17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=9.66,
#         reward=0.00,
#
# (-3.0, 1.0)
# Percentiles before: [ 8.32458759 13.7095212  17.20430245]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [18.32093406 23.70950452 27.20430194]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=15.76,
#         reward=0.00,
#
# (3.0, -3.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819  1.06401545]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=2.79,
#         reward=30.21,
#
# (3.0, 3.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819  1.06401545]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=8.32,
#         reward=0.00,
#
# (-0.5, -2.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=11.22,
#         reward=0.00,
#
# (1.5, -1.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [-0.23913282  0.31439819  1.06401545]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=1.87,
#         reward=34.18,
#
# (-2.5, -1.0)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=4.73,
#         reward=61.17,
#
# (-2.5, 1.5)
# Percentiles before: [1.36837585 3.98376337 7.21537755]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [ 8.32458759 13.7095212  17.20430245]
# Counts after: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
#
#         buckets_a=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         buckets_b=(np.int64(25), np.int64(25), np.int64(25), np.int64(25)),
#         mean_diff=4.84,
#         reward=64.93,
#
# (-2.0, 0.5)
# Percentiles before: [-0.23913282  0.31439819  1.06401545]
# Counts before: Q1 (0–25%): 25, Q2 (25–50%): 25, Q3 (50–75%): 25, Q4 (75–100%): 25
# Percentiles after: [1.36837585 3.98376337 7.21537755]
# ...
#                                                                                                                         (-0.5, 0.5): np.float64(20.380011770073025),
#                                                                                                                         (-0.5, 1.0): np.float64(34.59313866159076),
#                                                                                                                         (-0.5, 1.5): np.float64(27.666608073505046),
#                                                                                                                         (-0.5, 2.0): np.float64(20.808206294702924),
#                                                                                                                         (-0.5, 2.5): np.float64(19.879027837190417),
#                                                                                                                         (-0.5, 3.0): np.float64(40.08178578009561),
#                                                                                                                         (0.0, -3.0): np.float64(16.62410797762472),
#                                                                                                                         (0.0, -2.5): np.float64(42.39700303087998),
#                                                                                                                         (0.0, -2.0): np.float64(35.48297329662235),
#                                                                                                                         (0.0, -1.5): np.float64(29.65267369606249),
#                                                                                                                         (0.0, -1.0): np.float64(15.436426138113783),
#                                                                                                                         (0.0, -0.5): np.float64(44.06462915860205),
#                                                                                                                         (0.0, 0.0): np.float64(27.726770217406013),
#                                                                                                                         (0.0, 0.5): np.float64(54.78015904540204),
#                                                                                                                         (0.0, 1.0): np.float64(16.081726239221876),
#                                                                                                                         (0.0, 1.5): np.float64(29.323137184050076),
#                                                                                                                         (0.0, 2.0): np.float64(17.563429849386626),
#                                                                                                                         (0.0, 2.5): np.float64(23.047961656186764),
#                                                                                                                         (0.0, 3.0): np.float64(36.837492023443744),
#                                                                                                                         (0.5, -3.0): np.float64(49.00039549297581),
#                                                                                                                         (0.5, -2.5): np.float64(15.12790069141787),
#                                                                                                                         (0.5, -2.0): np.float64(11.379112425433894),
#                                                                                                                         (0.5, -1.5): np.float64(23.179160560268592),
#                                                                                                                         (0.5, -1.0): np.float64(32.319686670663785),
#                                                                                                                         (0.5, -0.5): np.float64(32.41652514576542),
#                                                                                                                         (0.5, 0.0): np.float64(13.430680588564247),
#                                                                                                                         (0.5, 0.5): np.float64(38.98686439887405),
#                                                                                                                         (0.5, 1.0): np.float64(35.618828469037),
#                                                                                                                         (0.5, 1.5): np.float64(34.743670283306024),
#                                                                                                                         (0.5, 2.0): np.float64(30.565649823182092),
#                                                                                                                         (0.5, 2.5): np.float64(34.4712057187418),
#                                                                                                                         (0.5, 3.0): np.float64(24.91944073778969),
#                                                                                                                         (1.0, -3.0): np.float64(26.966187306589894),
#                                                                                                                         (1.0, -2.5): np.float64(12.235747388696034),
#                                                                                                                         (1.0, -2.0): np.float64(44.997650716859084),
#                                                                                                                         (1.0, -1.5): np.float64(44.94671621070707),
#                                                                                                                         (1.0, -1.0): np.float64(31.079188715632554),
#                                                                                                                         (1.0, -0.5): np.float64(30.957442911137527),
#                                                                                                                         (1.0, 0.0): np.float64(14.016507147810511),
#                                                                                                                         (1.0, 0.5): np.float64(34.39433614115999),
#                                                                                                                         (1.0, 1.0): np.float64(10.88807151339737),
#                                                                                                                         (1.0, 1.5): np.float64(33.5579164113458),
#                                                                                                                         (1.0, 2.0): np.float64(46.074081766085854),
#                                                                                                                         (1.0, 2.5): np.float64(21.1388374788665),
#                                                                                                                         (1.0, 3.0): np.float64(15.395918751637975),
#                                                                                                                         (1.5, -3.0): np.float64(23.817710359641723),
#                                                                                                                         (1.5, -2.5): np.float64(10.820170069634871),
#                                                                                                                         (1.5, -2.0): np.float64(38.239050776391565),
#                                                                                                                         (1.5, -1.5): np.float64(48.280077744599595),
#                                                                                                                         (1.5, -1.0): np.float64(32.82627534104771),
#                                                                                                                         (1.5, -0.5): np.float64(37.76527087873314),
#                                                                                                                         (1.5, 0.0): np.float64(25.8158661620031),
#                                                                                                                         (1.5, 0.5): np.float64(39.78387200553304),
#                                                                                                                         (1.5, 1.0): np.float64(23.45103337237056),
#                                                                                                                         (1.5, 1.5): np.float64(38.2685917134562),
#                                                                                                                         (1.5, 2.0): np.float64(18.53080840141951),
#                                                                                                                         (1.5, 2.5): np.float64(26.09294218675472),
#                                                                                                                         (1.5, 3.0): np.float64(21.98888011955885),
#                                                                                                                         (2.0, -3.0): np.float64(34.65068981976894),
#                                                                                                                         (2.0, -2.5): np.float64(4.655912368263805),
#                                                                                                                         (2.0, -2.0): np.float64(16.181891418721868),
#                                                                                                                         (2.0, -1.5): np.float64(26.463983840471638),
#                                                                                                                         (2.0, -1.0): np.float64(26.57666379920446),
#                                                                                                                         (2.0, -0.5): np.float64(43.749491172027724),
#                                                                                                                         (2.0, 0.0): np.float64(25.87931200062747),
#                                                                                                                         (2.0, 0.5): np.float64(15.706646488665939),
#                                                                                                                         (2.0, 1.0): np.float64(33.26213335250888),
#                                                                                                                         (2.0, 1.5): np.float64(38.87119939905785),
#                                                                                                                         (2.0, 2.0): np.float64(42.943579992562306),
#                                                                                                                         (2.0, 2.5): np.float64(27.78806377646143),
#                                                                                                                         (2.0, 3.0): np.float64(15.186532168991342),
#                                                                                                                         (2.5, -3.0): np.float64(37.8844222698796),
#                                                                                                                         (2.5, -2.5): np.float64(13.388656887164252),
#                                                                                                                         (2.5, -2.0): np.float64(46.31375375810689),
#                                                                                                                         (2.5, -1.5): np.float64(24.70822249856222),
#                                                                                                                         (2.5, -1.0): np.float64(31.66372956683029),
#                                                                                                                         (2.5, -0.5): np.float64(20.347189057624902),
#                                                                                                                         (2.5, 0.0): np.float64(32.1430257358344),
#                                                                                                                         (2.5, 0.5): np.float64(34.916658048810085),
#                                                                                                                         (2.5, 1.0): np.float64(27.661511583774626),
#                                                                                                                         (2.5, 1.5): np.float64(40.06506362618596),
#                                                                                                                         (2.5, 2.0): np.float64(15.799225076025289),
#                                                                                                                         (2.5, 2.5): np.float64(38.0587249304629),
#                                                                                                                         (2.5, 3.0): np.float64(39.4081787452408),
#                                                                                                                         (3.0, -3.0): np.float64(44.76207456336589),
#                                                                                                                         (3.0, -2.5): np.float64(8.09587617077215),
#                                                                                                                         (3.0, -2.0): np.float64(29.126263680887693),
#                                                                                                                         (3.0, -1.5): np.float64(12.911529587882882),
#                                                                                                                         (3.0, -1.0): np.float64(30.117388034374905),
#                                                                                                                         (3.0, -0.5): np.float64(24.184829016368),
#                                                                                                                         (3.0, 0.0): np.float64(45.06184724896259),
#                                                                                                                         (3.0, 0.5): np.float64(37.12308196032744),
#                                                                                                                         (3.0, 1.0): np.float64(22.15564574586269),
#                                                                                                                         (3.0, 1.5): np.float64(27.90564410696035),
#                                                                                                                         (3.0, 2.0): np.float64(38.9824847408965),
#                                                                                                                         (3.0, 2.5): np.float64(14.985711370209325),
#                                                                                                                         (3.0, 3.0): np.float64(28.494097983125936)}}

# %%
s = list(range(1, 11, 1))
sn = [s for i in range(1, 11, 1)]
sn = np.vstack(sn)
sn = sn + sn.T
for i in range(2, 20):
    print(i,':', np.count_nonzero(sn == i))

class CPU():
    def __init__(self, choices):
        self.choices = choices
        cpu_pick = random.choice(choices)
        matrix = np.vstack([choices for _ in range(len(choices))])
        matrix = matrix + matrix.T
        self.matrix = matrix
    
    def guess(self):
        choice, count = np.unique(self.matrix, return_counts=True)
        probs = [(num, mode/len(count)) for num, mode in zip(choice, count)]
        for i, j in probs:
            print(f"{i}: {j:.2f}")
        likely = max(probs, key=lambda x: x[1])
        return likely[0]
    
    def self_update(self, choice):
        self.matrix = np.where(self.matrix == choice, np.nan, self.matrix)

    def opp_update(self, choice):
        min_total = self.cpu_guess + 1
        self.matrix = np.where(self.matrix < min_total, np.nan, self.matrix)
        
user_beads = input("Choose a number between 1 and 10: ")
total_beads = int(user_beads) + cpu_beads
# Out:
# 2 : 1
# 3 : 2
# 4 : 3
# 5 : 4
# 6 : 5
# 7 : 6
# 8 : 7
# 9 : 8
# 10 : 9
# 11 : 10
# 12 : 9
# 13 : 8
# 14 : 7
# 15 : 6
# 16 : 5
# 17 : 4
# 18 : 3
# 19 : 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[151], line 32
#      29         self.matrix = np.where(self.matrix < min_total, np.nan, self.matrix)
#      31 user_beads = input("Choose a number between 1 and 10: ")
# ---> 32 total_beads = int(user_beads) + cpu_beads
#
# ValueError: invalid literal for int() with base 10: ''
